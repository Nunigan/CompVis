# %% [markdown]
# # FCNs for semantic segmentation
#
# In this exercise we will look at the basics how to build a fully convolutional network for semantic segmentation.
#
# ## A first example

# %%
# install all needed packages
from typing import Tuple
import numpy as np
import skimage
import skimage.data
import skimage.io
import tensorflow.keras as keras

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# workaround for TF1.15 bug "Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR"
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# for displaying images in jupyter
from matplotlib import pyplot as plt

# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 10]
#mpl.rcParams['figure.dpi']= 400

# %%
# check tensorflow installation to see if we have GPU support
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15034965683288902234
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1876827467339993253
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9849690164849693702
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2304311296
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4575379636730443899
# physical_device_desc: "device: 0, name: GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]

# %% [markdown]
# ### Images for smoke tests
#
# When building a new network, it is a good idea to check if the network works at all, as it can sometimes take a while until all the parameters are fixed. For that we generate some function to create some simple test images that we can use.

# %%
def gen_random_binary_test_image(height: int, width: int)->(np.ndarray, np.ndarray):
    """
    Generate a test image and an appropriate label image with label 0 or label 1
    Label 0 images have a lower medium grayscale value, label 1 images a higher one.
    
    The returned images will have shape (height, width, 1) and type uint8 to be as compatible as possible to 
    mages read from files
    """
    VALUE = [100.0, 200.0]
    CLASS_ID = [0, 1]
    NOISE = 20.0
    
    label = np.zeros((height, width, 1), dtype=np.uint8)
    class_id = np.random.choice(CLASS_ID)
    label.fill(class_id)
    img = np.random.normal(VALUE[class_id], NOISE, ((height, width, 1))).astype(np.uint8)
    
    return img, label

# %%
image, label = gen_random_binary_test_image(128, 128)
print('mean: {}'.format(np.mean(image)))
print('mask: {}'.format(np.max(label)))
plt.imshow(image.reshape((image.shape[0], image.shape[1])))
# Out:
# mean: 198.85321044921875
# mask: 1

# %% [markdown]
# ### Batch of data
#
# Training is usually done using a batch of data. For semantic segmentation, that will be a batch of image (patches). We will also add the normalization of the data in this step.
#
# We will just scale the images in the range 0.0 to 1.0 from the full range of 0 to 255. Other possibilities are to scale the images individually according to their minimum and maximum values.
#
# We will also convert the label images to a 1d Array to match the output of the network (we will see about that in the next step).

# %%
def gen_batch_binary(batch_size, height: int, width: int):
    image_list = []
    label_list = []
    for i in range(batch_size):
        img, label = gen_random_binary_test_image(height=height, width=width)
        image_list.append(img.astype(np.float32) / 255.0)
        label_list.append(label.astype(np.float32))

    image_batch = np.array(image_list, dtype=np.float32)
    label_batch = np.array(label_list, dtype=np.float32)

    # reshape labels as this is not done in the model
    label_batch = label_batch.reshape(batch_size, height,width, 1)

    return image_batch, label_batch

# %%
image_batch, label_batch = gen_batch_binary(100, 128, 128)
print(image_batch.shape)
print(label_batch.shape)
# Out:
# (100, 128, 128, 1)
# (100, 128, 128, 1)

# %% [markdown]
# ## Simple FCN
#
# We will create a simple fully convolutional neural network for processing a batch of image patches

# %%
def fcn_simple_no_border(input_height:int, input_width:int) -> keras.Model:
    """
    Create a simple fcn model for semantic segmentation with 2 classes
    """
    model = keras.Sequential()
    
    # we use grayscale (1-channel input)
    
    # (used to define input shape on the first layers)
    model.add(keras.layers.Layer(input_shape=(input_height , input_width, 1)))
    
    # add 3 convolutional layers with 3x3 filters
    model.add(keras.layers.Convolution2D(filters=4, kernel_size=3, padding='same', activation='relu'))
    model.add(keras.layers.Convolution2D(filters=8, kernel_size=3, padding='same', activation='relu'))
    model.add(keras.layers.Convolution2D(filters=4, kernel_size=3, padding='same', activation='relu'))
    
    # go to logits which is the number of classes and add sigmoid layer for activation
    model.add(keras.layers.Convolution2D(filters=1, kernel_size=1, activation=None, 
                                         kernel_initializer=keras.initializers.TruncatedNormal(mean=0.0, stddev=0.001, seed=None)))
    model.add(keras.layers.Activation('sigmoid'))
    
    # reshape so that we have a sample for each pixel
    model.add(keras.layers.Reshape(target_shape=(input_height, input_width, 1)))
    
    return model

# %%
model = fcn_simple_no_border(128, 128)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer (Layer)                (None, 128, 128, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 4)       40
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       296
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 4)       292
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 1)       5
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 1)       0
# _________________________________________________________________
# reshape (Reshape)            (None, 128, 128, 1)       0
# =================================================================
# Total params: 633
# Trainable params: 633
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Lets see if the model works....

# %%
history = model.fit(image_batch, label_batch, epochs=50, batch_size = 10, verbose=1)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6930 - accuracy: 0.4714
# Epoch 2/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6916 - accuracy: 0.5073
# Epoch 3/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6893 - accuracy: 0.4774
# Epoch 4/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6860 - accuracy: 0.4783
# Epoch 5/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6799 - accuracy: 0.4795
# Epoch 6/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6704 - accuracy: 0.4827
# Epoch 7/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6573 - accuracy: 0.4847
# Epoch 8/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6418 - accuracy: 0.4822
# Epoch 9/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6226 - accuracy: 0.4886
# Epoch 10/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5981 - accuracy: 0.5204
# Epoch 11/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5740 - accuracy: 0.5122
# Epoch 12/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5435 - accuracy: 0.6646
# Epoch 13/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5155 - accuracy: 0.6866
# Epoch 14/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4914 - accuracy: 0.8194
# Epoch 15/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4639 - accuracy: 0.8920
# Epoch 16/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4429 - accuracy: 0.8824
# Epoch 17/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4202 - accuracy: 0.9274
# Epoch 18/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4031 - accuracy: 0.9436
# Epoch 19/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3900 - accuracy: 0.9541
# Epoch 20/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3775 - accuracy: 0.9746
# Epoch 21/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3661 - accuracy: 0.9758
# Epoch 22/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3568 - accuracy: 0.9863
# Epoch 23/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3495 - accuracy: 0.9891
# Epoch 24/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3423 - accuracy: 0.9907
# Epoch 25/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3375 - accuracy: 0.9932
# Epoch 26/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3321 - accuracy: 0.9952
# Epoch 27/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3277 - accuracy: 0.9970
# Epoch 28/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3246 - accuracy: 0.9964
# Epoch 29/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3207 - accuracy: 0.9980
# Epoch 30/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3177 - accuracy: 0.9982
# Epoch 31/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3150 - accuracy: 0.9986
# Epoch 32/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3118 - accuracy: 0.9991
# Epoch 33/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3091 - accuracy: 0.9992
# Epoch 34/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3066 - accuracy: 0.9993
# Epoch 35/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3040 - accuracy: 0.9995
# Epoch 36/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3014 - accuracy: 0.9996
# Epoch 37/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2989 - accuracy: 0.9997
# Epoch 38/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2965 - accuracy: 0.9997
# Epoch 39/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2942 - accuracy: 0.9998
# Epoch 40/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2919 - accuracy: 0.9999
# Epoch 41/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2897 - accuracy: 0.9998
# Epoch 42/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2874 - accuracy: 0.9999
# Epoch 43/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2851 - accuracy: 0.9999
# Epoch 44/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2830 - accuracy: 0.9999
# Epoch 45/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2808 - accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2787 - accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2766 - accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2745 - accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2724 - accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2704 - accuracy: 1.0000

# %%
# Plot training accuracy values
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %%
print('min, max, mean: {},{}, {}'.format(np.min(image_batch), np.max(image_batch), np.mean(image_batch)))
# Out:
# min, max, mean: 0.0,1.0, 0.5734332799911499

# %% [markdown]
# ## Training with generators
#
# Reading the whole data set into memory is not always possible. There are different possibilities to that problem, one is to use the Dataset classes in the tensorflow backend. We will look at that a bit more in the next lecture. The other possibility is to use *generators* from python. A generator function to use for keras will generate a batch of data at the time.

# %%
def batch_generator(batch_size, height: int, width: int):
    while True:
        image_batch, label_batch = gen_batch_binary(batch_size=batch_size, height=height, width=width)
        yield image_batch, label_batch

# %% [markdown]
# In order to use the generator, we use the ```model.fit_generator``` function.

# %%
PATCH_HEIGHT = 128
PATCH_WIDTH = 128
BATCH_SIZE = 50
EPOCHS = 50
STEPS_PER_EPOCHS = 10
model = fcn_simple_no_border(PATCH_HEIGHT, PATCH_WIDTH)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit_generator(
        generator=batch_generator(BATCH_SIZE, PATCH_HEIGHT, PATCH_WIDTH),
        epochs=EPOCHS,
        verbose=1,
        steps_per_epoch=STEPS_PER_EPOCHS,
        shuffle=False,
        callbacks=None)
# Out:
# WARNING:tensorflow:From <ipython-input-15-e0377214b005>:14: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
#  1/10 [==>...........................] - ETA: 0s - loss: 0.6932 - accuracy: 0.4400WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0043s vs `on_train_batch_end` time: 0.0087s). Check your callbacks.
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6927 - accuracy: 0.5280
# Epoch 2/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.6919 - accuracy: 0.5020
# Epoch 3/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.6899 - accuracy: 0.4900
# Epoch 4/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.6828 - accuracy: 0.5400
# Epoch 5/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.6754 - accuracy: 0.5160
# Epoch 6/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.6711 - accuracy: 0.4680
# Epoch 7/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.6570 - accuracy: 0.4760
# Epoch 8/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.6278 - accuracy: 0.5100
# Epoch 9/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.5997 - accuracy: 0.5320
# Epoch 10/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.5855 - accuracy: 0.5280
# Epoch 11/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.5862 - accuracy: 0.4966
# Epoch 12/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.5691 - accuracy: 0.4973
# Epoch 13/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.5256 - accuracy: 0.5484
# Epoch 14/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.5041 - accuracy: 0.5307
# Epoch 15/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.4566 - accuracy: 0.8200
# Epoch 16/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4501 - accuracy: 0.8986
# Epoch 17/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3936 - accuracy: 0.9484
# Epoch 18/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3519 - accuracy: 0.9707
# Epoch 19/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3705 - accuracy: 0.9884
# Epoch 20/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3316 - accuracy: 0.9880
# Epoch 21/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3292 - accuracy: 0.9943
# Epoch 22/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3081 - accuracy: 0.9964
# Epoch 23/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3001 - accuracy: 0.9951
# Epoch 24/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3294 - accuracy: 0.9981
# Epoch 25/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3031 - accuracy: 0.9979
# Epoch 26/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.2900 - accuracy: 0.9987
# Epoch 27/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3010 - accuracy: 0.9987
# Epoch 28/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.2841 - accuracy: 0.9991
# Epoch 29/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2864 - accuracy: 0.9990
# Epoch 30/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.2965 - accuracy: 0.9994
# Epoch 31/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2770 - accuracy: 0.9994
# Epoch 32/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2721 - accuracy: 0.9995
# Epoch 33/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2747 - accuracy: 0.9996
# Epoch 34/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2795 - accuracy: 0.9996
# Epoch 35/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2979 - accuracy: 0.9997
# Epoch 36/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2668 - accuracy: 0.9997
# Epoch 37/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.2652 - accuracy: 0.9997
# Epoch 38/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2687 - accuracy: 0.9996
# Epoch 39/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2644 - accuracy: 0.9995
# Epoch 40/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2593 - accuracy: 0.9997
# Epoch 41/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2424 - accuracy: 0.9997
# Epoch 42/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2412 - accuracy: 0.9998
# Epoch 43/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2431 - accuracy: 0.9999
# Epoch 44/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2498 - accuracy: 0.9999
# Epoch 45/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2605 - accuracy: 0.9999
# Epoch 46/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.2504 - accuracy: 0.9999
# Epoch 47/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2415 - accuracy: 0.9999
# Epoch 48/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2461 - accuracy: 0.9999
# Epoch 49/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2545 - accuracy: 0.9999
# Epoch 50/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.2383 - accuracy: 0.9999

# %% [markdown]
# ## Exercise 1: Categorical data
#
# In the example above we had only two classes, but in most applications we want to classify into more classes, as you have for example already done in the first homework, when classifying number.
#
# Change the network and the generation of examples to use 5 classes.

# %%
# see solution below that uses both padding and categorical data

# %% [markdown]
# ## Exercise 2: Padding
#
# Also in the example, we used padding for the convolutional filters by specifying ```padding='same'```. However this will not process the data at the edges correctly as the missing data will be filled with 0. For training it is preferable to use only the data that fits inside the convolutional filters. This can be specified using ```padding='valid'```. However then the labels will have to be resized accordingly.
#
# Change the network to use *valid* padding.

# %%
def fcn_simple_border(input_height:int, input_width:int, nr_classes:int) -> (keras.Model, int):
    """
    Create a simple fcn model for semantic segmentation with 2 classes.
    Return both the model and the border size
    """
    model = keras.Sequential()
    border = 0;
    
    # we use grayscale (1-channel input)
    
    # (used to define input shape on the first layers)
    model.add(keras.layers.Layer(input_shape=(input_height , input_width, 1)))
    
    # add 3 convolutional layers with 3x3 filters
    model.add(keras.layers.Convolution2D(filters=4, kernel_size=3, padding='valid', activation='relu'))
    border = border + 1
    model.add(keras.layers.Convolution2D(filters=8, kernel_size=3, padding='valid', activation='relu'))
    border = border + 1
    model.add(keras.layers.Convolution2D(filters=4, kernel_size=3, padding='valid', activation='relu'))
    border = border + 1
    
    # go to logits which is the number of classes and add softmax layer for activation
    model.add(keras.layers.Convolution2D(filters=nr_classes, kernel_size=1, activation=None, 
                                         kernel_initializer=keras.initializers.TruncatedNormal(mean=0.0, stddev=0.001, seed=None)))
    model.add(keras.layers.Activation('softmax'))
    
    # reshape so that we have a sample for each pixel
   
    return model, border

# %%
model, border = fcn_simple_border(128, 128, 5)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_2 (Layer)              (None, 128, 128, 1)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 126, 126, 4)       40
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 124, 124, 8)       296
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 122, 122, 4)       292
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 122, 122, 5)       25
# _________________________________________________________________
# activation_2 (Activation)    (None, 122, 122, 5)       0
# =================================================================
# Total params: 653
# Trainable params: 653
# Non-trainable params: 0
# _________________________________________________________________

# %%
def gen_random_binary_test_image_classes(height: int, width: int, nr_classes)->(np.ndarray, np.ndarray):
    """
    Generate a test image and an appropriate label image with label 0 or label 1
    Label 0 images have a lower medium grayscale value, label 1 images a higher one.
    
    The returned images will have shape (height, width, 1) and type uint8 to be as compatible as possible to 
    mages read from files
    """
    class_id = np.random.choice(range(nr_classes))
    value = 255.0 * class_id / nr_classes 
    
    NOISE = 20.0
    
    label = np.zeros((height, width, 1), dtype=np.uint8)
    label.fill(class_id)
    img = np.random.normal(value, NOISE, ((height, width, 1))).astype(np.uint8)
    
    return img, label

def gen_batch_binary_with_border(batch_size, height: int, width: int, border: int, nr_classes:int):
    image_list = []
    label_list = []
    for i in range(batch_size):
        img, label = gen_random_binary_test_image_classes(height=height, width=width, nr_classes=nr_classes)
        label = label[border:-border, border:-border]
        image_list.append(img.astype(np.float32) / 255.0)
        label_list.append(label.astype(np.float32))

    image_batch = np.array(image_list, dtype=np.float32)
    label_batch = np.array(label_list, dtype=np.float32)

    # reshape labels as this is not done in the model
    # label_batch = label_batch.reshape(batch_size, (height-2*border)*(width-2*border), 1)
    label_batch = keras.utils.to_categorical(label_batch, num_classes=nr_classes)

    return image_batch, label_batch

def batch_generator_with_border(batch_size, height: int, width: int, border: int, nr_classes:int):
    while True:
        image_batch, label_batch = gen_batch_binary_with_border(batch_size=batch_size, 
                                                                height=height, width=width, 
                                                                border=border, nr_classes=nr_classes)
        yield image_batch, label_batch

# %%
PATCH_HEIGHT = 128
PATCH_WIDTH = 128
BATCH_SIZE = 128
EPOCHS = 50
STEPS_PER_EPOCHS = 100
NR_CLASSES = 5
model, border = fcn_simple_border(PATCH_HEIGHT, PATCH_WIDTH, NR_CLASSES)
model.compile(optimizer='adagrad', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit_generator(
        generator=batch_generator_with_border(BATCH_SIZE, PATCH_HEIGHT, PATCH_WIDTH, border, NR_CLASSES),
        epochs=EPOCHS,
        verbose=1,
        steps_per_epoch=STEPS_PER_EPOCHS,
        shuffle=False,
        callbacks=None)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 11s 112ms/step - loss: 1.6094 - accuracy: 0.1989
# Epoch 2/50
# 100/100 [==============================] - 11s 113ms/step - loss: 1.6094 - accuracy: 0.2043
# Epoch 3/50
# 100/100 [==============================] - 11s 111ms/step - loss: 1.6094 - accuracy: 0.2444
# Epoch 4/50
# 100/100 [==============================] - 11s 114ms/step - loss: 1.6094 - accuracy: 0.2282
# Epoch 5/50
# 100/100 [==============================] - 11s 114ms/step - loss: 1.6094 - accuracy: 0.2847
# Epoch 6/50
# 100/100 [==============================] - 11s 112ms/step - loss: 1.6094 - accuracy: 0.2275
# Epoch 7/50
# 100/100 [==============================] - 11s 111ms/step - loss: 1.6094 - accuracy: 0.2102
# Epoch 8/50
# 100/100 [==============================] - 11s 112ms/step - loss: 1.6094 - accuracy: 0.2161
# Epoch 9/50
# 100/100 [==============================] - 11s 112ms/step - loss: 1.6094 - accuracy: 0.2513
# Epoch 10/50
# 100/100 [==============================] - 11s 109ms/step - loss: 1.6093 - accuracy: 0.2556
# Epoch 11/50
# 100/100 [==============================] - 11s 113ms/step - loss: 1.6093 - accuracy: 0.2004
# Epoch 12/50
# 100/100 [==============================] - 11s 114ms/step - loss: 1.6093 - accuracy: 0.1977
# Epoch 13/50
# 100/100 [==============================] - 12s 115ms/step - loss: 1.6093 - accuracy: 0.1981
# Epoch 14/50
# 100/100 [==============================] - 11s 112ms/step - loss: 1.6093 - accuracy: 0.2030
# Epoch 15/50
# 100/100 [==============================] - 11s 111ms/step - loss: 1.6093 - accuracy: 0.2038
# Epoch 16/50
# 100/100 [==============================] - 11s 111ms/step - loss: 1.6093 - accuracy: 0.2062
# Epoch 17/50
# 100/100 [==============================] - 11s 113ms/step - loss: 1.6092 - accuracy: 0.2059
# Epoch 18/50
# 100/100 [==============================] - 11s 111ms/step - loss: 1.6092 - accuracy: 0.2002
# Epoch 19/50
# 100/100 [==============================] - 11s 115ms/step - loss: 1.6092 - accuracy: 0.2005
# Epoch 20/50
# 100/100 [==============================] - 11s 108ms/step - loss: 1.6092 - accuracy: 0.2021
# Epoch 21/50
# 100/100 [==============================] - 11s 112ms/step - loss: 1.6092 - accuracy: 0.1977
# Epoch 22/50
# 100/100 [==============================] - 11s 109ms/step - loss: 1.6092 - accuracy: 0.2059
# Epoch 23/50
# 100/100 [==============================] - 11s 109ms/step - loss: 1.6092 - accuracy: 0.1977
# Epoch 24/50
# 100/100 [==============================] - 11s 107ms/step - loss: 1.6092 - accuracy: 0.1936
# Epoch 25/50
# 100/100 [==============================] - 11s 112ms/step - loss: 1.6092 - accuracy: 0.2006
# Epoch 26/50
# 100/100 [==============================] - 11s 112ms/step - loss: 1.6091 - accuracy: 0.2020
# Epoch 27/50
# 100/100 [==============================] - 11s 112ms/step - loss: 1.6091 - accuracy: 0.2005
# Epoch 28/50
# 100/100 [==============================] - 11s 110ms/step - loss: 1.6091 - accuracy: 0.2044
# Epoch 29/50
# 100/100 [==============================] - 11s 113ms/step - loss: 1.6091 - accuracy: 0.1961
# Epoch 30/50
# 100/100 [==============================] - 11s 105ms/step - loss: 1.6091 - accuracy: 0.1976
# Epoch 31/50
# 100/100 [==============================] - 10s 103ms/step - loss: 1.6091 - accuracy: 0.1950
# Epoch 32/50
# 100/100 [==============================] - 10s 103ms/step - loss: 1.6090 - accuracy: 0.2044
# Epoch 33/50
# 100/100 [==============================] - 10s 102ms/step - loss: 1.6091 - accuracy: 0.1980
# Epoch 34/50
# 100/100 [==============================] - 11s 107ms/step - loss: 1.6090 - accuracy: 0.1998
# Epoch 35/50
# 100/100 [==============================] - 10s 105ms/step - loss: 1.6091 - accuracy: 0.1937
# Epoch 36/50
# 100/100 [==============================] - 11s 109ms/step - loss: 1.6090 - accuracy: 0.2016
# Epoch 37/50
# 100/100 [==============================] - 11s 109ms/step - loss: 1.6089 - accuracy: 0.2087
# Epoch 38/50
# 100/100 [==============================] - 11s 108ms/step - loss: 1.6089 - accuracy: 0.2050
# Epoch 39/50
# 100/100 [==============================] - 11s 109ms/step - loss: 1.6090 - accuracy: 0.1963
# Epoch 40/50
# 100/100 [==============================] - 11s 110ms/step - loss: 1.6089 - accuracy: 0.1977
# Epoch 41/50
# 100/100 [==============================] - ETA: 0s - loss: 1.6089 - accuracy: 0.19 - 11s 110ms/step - loss: 1.6089 - accuracy: 0.1982
# Epoch 42/50
# 100/100 [==============================] - 11s 110ms/step - loss: 1.6089 - accuracy: 0.2032
# Epoch 43/50
# 100/100 [==============================] - 11s 110ms/step - loss: 1.6089 - accuracy: 0.2009
# Epoch 44/50
# 100/100 [==============================] - 11s 109ms/step - loss: 1.6089 - accuracy: 0.1984
# Epoch 45/50
# 100/100 [==============================] - 11s 106ms/step - loss: 1.6089 - accuracy: 0.1988
# Epoch 46/50
# 100/100 [==============================] - 11s 109ms/step - loss: 1.6088 - accuracy: 0.2030
# Epoch 47/50
# 100/100 [==============================] - 11s 108ms/step - loss: 1.6088 - accuracy: 0.2036
# Epoch 48/50
# 100/100 [==============================] - 11s 106ms/step - loss: 1.6088 - accuracy: 0.1997
# Epoch 49/50
# 100/100 [==============================] - 11s 107ms/step - loss: 1.6087 - accuracy: 0.2023
# Epoch 50/50
# 100/100 [==============================] - 11s 108ms/step - loss: 1.6087 - accuracy: 0.2009

# %%
# Plot training accuracy values
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# Plot training loss values
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %% [markdown]
# ## Exercise 3: Data preparation for homework 2
#
# In the homework, you should train a network to recognise different texture categories from the describable texture data base. If you have already downloaded the data and/or extracted it, copy it to the current folder for this exercise (otherwise it will download again). The following function will download and prepare the dataset by converting it to grayscale, extract a smaller region in the center and renaming the files consecutively. It will also divide the data into 3 sets for training, validation and testing.

# %%
from dtd_loader_main import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-bd739292a3f9> in <module>
# ----> 1 from dtd_loader_main import *
#
# ModuleNotFoundError: No module named 'dtd_loader_main'

# %%
download_and_convert()
